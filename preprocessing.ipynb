# %%
# All the imports

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# path to no dart image
path = r'C:\Users\alont\OneDrive\Documents\Senior_2nd_Sem\SDP\Image_Processing_Repo\Images\IMG-2157.jpg'

#read image 
no_dart_image = cv2.imread(path)  

# convert to color and print
no_dart_image = cv2.cvtColor(no_dart_image, cv2.COLOR_BGR2RGB)
plt.imshow(no_dart_image)
plt.show()

# %%
# path to dart image
path = r'C:\Users\alont\OneDrive\Documents\Senior_2nd_Sem\SDP\Image_Processing_Repo\Images\IMG-2158.jpg'

#read image 
dart_image = cv2.imread(path)  

# convert to color and print
dart_image = cv2.cvtColor(dart_image, cv2.COLOR_BGR2RGB)
plt.imshow(dart_image)
plt.show()
